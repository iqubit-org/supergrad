# %% [markdown]
# # Simulating time evolution
#
# In this subsection, we detail the workflow for simulating the time evolution of a quantum system using common function "Evolve". Our focus is on implementing a Cross-resonance (CR) pulse in a system of three qubits. The code provided forms the basis of our discussion.
#
# Initially, we set up the pulse parameters for our time evolution. We specify the length of the CR pulse and calculate the effective coupling strength $J_{eff}$ and the detuning between the dressed 0-1 frequencies of qubits 1 and 2. The driving amplitude of the pulse $\epsilon_d$ is computed based on the detuning and the effective coupling strength.

# %%
import numpy as np
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt

fluxonium_1 = {
    "ec": 1.0 * 2 * np.pi,
    "ej": 4.0 * 2 * np.pi,
    "el": 0.9 * 2 * np.pi,
    "phiext": np.pi,
    "system_type": "fluxonium",
    "arguments": {"phi_max": 5 * np.pi},
}

fluxonium_2 = {
    "ec": 1.0 * 2 * np.pi,
    "ej": 4.0 * 2 * np.pi,
    "el": 1.0 * 2 * np.pi,
    "phiext": np.pi,
    "system_type": "fluxonium",
    "arguments": {"phi_max": 5 * np.pi},
}

fluxonium_3 = {
    "ec": 1.0 * 2 * np.pi,
    "ej": 4.0 * 2 * np.pi,
    "el": 1.1 * 2 * np.pi,
    "phiext": np.pi,
    "system_type": "fluxonium",
    "arguments": {"phi_max": 5 * np.pi},
}

coupling = {
    "capacitive_coupling": {"strength": 20.0e-3 * 2 * np.pi},
    "inductive_coupling": {"strength": -1.0 * 2e-3 * 2 * np.pi},
}

# %%
from supergrad.quantum_system.graph import BaseGraph


class MultipathThreeQubit(BaseGraph):
    def __init__(self):
        super().__init__()

        # nodes represent qubits
        self.add_node("q1", **fluxonium_1)
        self.add_node("q2", **fluxonium_2)
        self.add_node("q3", **fluxonium_3)
        # edges represent two-qubit interactions
        self.add_edge("q1", "q2", **coupling)
        self.add_edge("q2", "q3", **coupling)

# %%
from supergrad.common_functions import Spectrum


chain_3q = MultipathThreeQubit()
spec = Spectrum(chain_3q, share_params=True, unify_coupling=True)
params = spec.static_params
energy = spec.energy_tensor(params)
dressed_freq_q1 = (energy[1, 0, 0] - energy[0, 0, 0])
dressed_freq_q2 = (energy[0, 1, 0] - energy[0, 0, 0])

# %%
from supergrad.common_functions import Evolve
from supergrad.utils import tensor, compute_fidelity_with_1q_rotation_axis
from supergrad.utils.gates import cnot

length = 100.0
detuning = jnp.abs(dressed_freq_q1 - dressed_freq_q2)
j_eff = 0.01 * 2 * np.pi
tau_eps_drive = np.pi / 2.0 * detuning / j_eff

cr_pulse = {
    "pulse": {
        "amp": tau_eps_drive / length,
        "omega_d": dressed_freq_q2,
        "phase": 0.0,
        "length": length,
        "pulse_type": "cos",
        "operator_type": "phi_operator",
        "delay": 0.0,
    }
}

# %% [markdown]
# Hence we define the MultipathThreeQubitCR class, inheriting the MultipathThreeQubit model. This class includes the CR pulse configuration, thereby customizing the qubit model for our specific experiment.

# %%
class MultipathThreeQubitCR(MultipathThreeQubit):
    def __init__(self):
        super().__init__()

        self.add_node("q1", **cr_pulse)

cr_chain_3q = MultipathThreeQubitCR()

# %% [markdown]
# The Evolve class is then utilized to simulate the time evolution. We specify parameters such as the truncated dimension, parameter sharing, and compensation options. The unitary evolution of the CR pulse is computed using the eigen\_basis method of the Evolve class.

# %%
target_unitary = tensor(cnot(), jnp.eye(2))
evo = Evolve(cr_chain_3q, truncated_dim=3, share_params=True, unify_coupling=True, compensation_option='no_comp')
params = evo.pulse_params
cr_unitary = evo.eigen_basis(evo.static_params)
fideity, res_unitary = compute_fidelity_with_1q_rotation_axis(target_unitary, cr_unitary, compensation_option='arbit_single', n_qubit=3)
print(fideity)  # 0.98824
# Out:
# 0.9882389768200743

# %% [markdown]
# The CR pulse, which contains an effective ZX term, can be utilized to implement a CNOT unitary. It is well-established that single-qubit gates generally exhibit lower error rates compared to two-qubit gates. Therefore, we can introduce virtual single-qubit rotations to simulate a CNOT unitary more accurately. For instance, we simulate a 3-qubit gate that is composed of a tensor product between a CNOT gate and an identity operation, and the possible compensations are calculated using a differentiable optimizer within the `compute_fidelity_with_1q_rotation_axis` function. Additionally, we compute the fidelity of the resultant unitary against the target unitary. The high fidelity(0.98824) indicates a successful implementation of the CNOT gate, demonstrating the effectiveness of our approach in simulating quantum gate operations in a multi-qubit system.
#
# Furthermore, we conduct pulse parameter optimization to simulate device calibration. This optimization process utilizes automatic differentiation to obtain gradients. After optimization, the fidelity of the $CNOT\otimes I$ gate is significantly enhanced, reaching up to 99.99\%. Consider the following code as an example:

# %%
import haiku as hk
from supergrad.utils.optimize import scipy_minimize

def infidelity(params):
    params = hk.data_structures.merge(evo.static_params, params)
    cr_unitary = evo.eigen_basis(params)
    fideity, res_unitary = compute_fidelity_with_1q_rotation_axis(target_unitary, cr_unitary, compensation_option='arbit_single', n_qubit=3)
    return jnp.abs(1 - fideity)

scipy_minimize(infidelity, params, method='L-BFGS-B', logging=True)
# Out:
# /Users/allegro/anaconda3/envs/aqgrad/lib/python3.11/site-packages/jax/_src/lax/lax.py:2660: ComplexWarning: Casting complex values to real discards the imaginary part
#   x_bar = _convert_element_type(x_bar, x.aval.dtype, x.aval.weak_type)
# step: 0
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.13067653633650167,
#                     'length': 100.0,
#                     'omega_d': 3.6580304111499444,
#                     'phase': 0.0}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.8874590856776485,
#                     'length': -0.0013356914947876548,
#                     'omega_d': -0.04429716346440153,
#                     'phase': 1.089402151817024e-05}}
# loss: 0.011761
# step: 1
# parameters:
# { 'q1_pulse_cos': { 'amp': 1.1294319972703935,
#                     'length': 100.0015032007628,
#                     'omega_d': 3.7078828884392716,
#                     'phase': -1.226024236880252e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': 0.21603797553751458,
#                     'length': 0.015263899413124081,
#                     'omega_d': 16.561186395737916,
#                     'phase': -5.798658440503154e-06}}
# loss: 0.236806
# step: 2
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.48488704961859685,
#                     'length': 100.00053311299371,
#                     'omega_d': 3.675710686512369,
#                     'phase': -4.348118145312327e-06}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.11384930032339519,
#                     'length': -0.003005125110153484,
#                     'omega_d': -13.918356118795202,
#                     'phase': 2.000631309262991e-05}}
# loss: 0.133322
# step: 3
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18142144826965967,
#                     'length': 100.0000763748418,
#                     'omega_d': 3.6605633230274237,
#                     'phase': -6.229201677679103e-07}}
# gradient:
# { 'q1_pulse_cos': { 'amp': 0.578299722278265,
#                     'length': 0.0013674763120677645,
#                     'omega_d': -0.10710757241447093,
#                     'phase': -6.46492962339755e-07}}
# loss: 0.007103
# step: 4
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.16166562538532375,
#                     'length': 100.0000362144186,
#                     'omega_d': 3.6624292385032216,
#                     'phase': -5.157461880642375e-07}}
# gradient:
# { 'q1_pulse_cos': { 'amp': 0.0842863687276961,
#                     'length': 0.00019312488211843996,
#                     'omega_d': -0.03007159193337304,
#                     'phase': 5.514881556251351e-06}}
# loss: 0.000199
# step: 5
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.15833689976947496,
#                     'length': 100.00002969718778,
#                     'omega_d': 3.663426471474998,
#                     'phase': -7.590132151453818e-07}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.018009363895589974,
#                     'length': -1.0316520632586204e-05,
#                     'omega_d': 0.0046567760579878615,
#                     'phase': 4.878887430781008e-06}}
# loss: 0.000073
# step: 6
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1589251731391586,
#                     'length': 100.00003002249618,
#                     'omega_d': 3.6632993631075474,
#                     'phase': -8.776913085692534e-07}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -8.933112302086409e-05,
#                     'length': 2.8003440674499247e-05,
#                     'omega_d': -0.0025668557253027626,
#                     'phase': 6.608171678312245e-06}}
# loss: 0.000068
# step: 7
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.15894129157839929,
#                     'length': 100.00002918426713,
#                     'omega_d': 3.6633772375828935,
#                     'phase': -1.0793872738416228e-06}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0005072234729614005,
#                     'length': 2.759252096447769e-05,
#                     'omega_d': -0.0023999270810986582,
#                     'phase': 6.686382677603351e-06}}
# loss: 0.000068
# step: 8
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.159005765335362,
#                     'length': 100.00002583135097,
#                     'omega_d': 3.6636887354842775,
#                     'phase': -1.8861711349311007e-06}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0023199623247769307,
#                     'length': 1.934015897180789e-05,
#                     'omega_d': -0.0016578272335478093,
#                     'phase': 4.329162736743061e-06}}
# loss: 0.000067
# step: 9
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.16028872881386041,
#                     'length': 99.99998199909417,
#                     'omega_d': 3.6677523959381984,
#                     'phase': -1.237911690830846e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.03558280203344098,
#                     'length': -3.909100043280963e-05,
#                     'omega_d': 0.026083961399973064,
#                     'phase': 6.319192463495149e-06}}
# loss: 0.000079
# step: 10
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.15940340768214173,
#                     'length': 100.00001224595921,
#                     'omega_d': 3.664948228452311,
#                     'phase': -5.1383600334346295e-06}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.008446908456668525,
#                     'length': 6.055275123214672e-06,
#                     'omega_d': 0.0018104175562377019,
#                     'phase': 2.7450147149745366e-06}}
# loss: 0.000065
# step: 11
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.16009472989270826,
#                     'length': 99.99999446798024,
#                     'omega_d': 3.666480468167226,
#                     'phase': -9.474209703794325e-06}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.015424765678364295,
#                     'length': -8.058309073523763e-06,
#                     'omega_d': 0.007822585821092506,
#                     'phase': 2.8454001073872533e-06}}
# loss: 0.000064
# step: 12
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.16041126340624964,
#                     'length': 99.99999044485189,
#                     'omega_d': 3.666627826735627,
#                     'phase': -1.058269090616204e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.009595739133361147,
#                     'length': 9.428077425903473e-06,
#                     'omega_d': 0.003979120854372604,
#                     'phase': 6.138962227014706e-06}}
# loss: 0.000060
# step: 13
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1622231305039394,
#                     'length': 99.99995742621626,
#                     'omega_d': 3.668737838306941,
#                     'phase': -1.9166863653475033e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.007288548319187748,
#                     'length': 9.272095522796345e-06,
#                     'omega_d': 0.0037609767816505876,
#                     'phase': 1.9428052561330852e-06}}
# loss: 0.000054
# step: 14
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.16476063005414524,
#                     'length': 99.99989890850745,
#                     'omega_d': 3.6714151834022117,
#                     'phase': -2.90264352046981e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.015540957504708632,
#                     'length': -7.991000734133019e-06,
#                     'omega_d': 0.015784084485323847,
#                     'phase': 5.341511340557793e-07}}
# loss: 0.000049
# step: 15
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.16733100807080578,
#                     'length': 99.99983790294826,
#                     'omega_d': 3.6729444066612693,
#                     'phase': -3.698636487159083e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0024736829316272793,
#                     'length': 5.1331600974662654e-05,
#                     'omega_d': -2.904030595777475e-06,
#                     'phase': 6.1055827595698536e-06}}
# loss: 0.000040
# step: 16
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.17486913342537355,
#                     'length': 99.99965956843346,
#                     'omega_d': 3.678779978752956,
#                     'phase': -6.277147300971073e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.06054213554897488,
#                     'length': -7.493913675838185e-05,
#                     'omega_d': 0.1333942410937461,
#                     'phase': 3.346816570394608e-06}}
# loss: 0.000123
# step: 17
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1688777990262368,
#                     'length': 99.99980130947155,
#                     'omega_d': 3.674141840997608,
#                     'phase': -4.227735834501282e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.007890025047078367,
#                     'length': 6.024742134715611e-07,
#                     'omega_d': 0.008989780661951424,
#                     'phase': 1.035773669450878e-08}}
# loss: 0.000037
# step: 18
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1722518841938033,
#                     'length': 99.99972041506075,
#                     'omega_d': 3.67633368913116,
#                     'phase': -5.313405443157647e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.016900343110455438,
#                     'length': -1.701903099195711e-05,
#                     'omega_d': 0.0285090019837398,
#                     'phase': 1.9016539473330936e-07}}
# loss: 0.000035
# step: 19
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.17263871579038412,
#                     'length': 99.99970797496157,
#                     'omega_d': 3.6762322340712816,
#                     'phase': -5.410601908132896e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.004335664883027167,
#                     'length': 2.5413164496531924e-05,
#                     'omega_d': 0.005157803154434097,
#                     'phase': 4.505560421934087e-06}}
# loss: 0.000030
# step: 20
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1752606239435135,
#                     'length': 99.99964185496893,
#                     'omega_d': 3.677548646727651,
#                     'phase': -6.223293291466641e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.004780210421322067,
#                     'length': 2.8689457916445094e-06,
#                     'omega_d': 0.006644085077605295,
#                     'phase': 5.611937472797369e-07}}
# loss: 0.000026
# step: 21
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18874892577165955,
#                     'length': 99.99932935362958,
#                     'omega_d': 3.684126191876034,
#                     'phase': -9.825698880027076e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.06657049895711475,
#                     'length': -0.00010822087036351938,
#                     'omega_d': 0.2314209626192396,
#                     'phase': -8.006819959670704e-06}}
# loss: 0.000190
# step: 22
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.17767953937169353,
#                     'length': 99.99958581275392,
#                     'omega_d': 3.678728226310143,
#                     'phase': -6.869328245885253e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.008086662969811833,
#                     'length': 8.636584311003745e-06,
#                     'omega_d': 0.01590066517278892,
#                     'phase': 1.649165126479803e-06}}
# loss: 0.000024
# step: 23
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1803321015637754,
#                     'length': 99.99952269701956,
#                     'omega_d': 3.679762765060259,
#                     'phase': -7.53583846229831e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.006124779396963337,
#                     'length': -7.415917397538188e-06,
#                     'omega_d': 0.012709406786398675,
#                     'phase': -1.9867346043902303e-06}}
# loss: 0.000021
# step: 24
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18398045502648833,
#                     'length': 99.99943956677039,
#                     'omega_d': 3.6810354618848065,
#                     'phase': -8.316624921550058e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0010349258921024606,
#                     'length': 1.370685126532691e-05,
#                     'omega_d': 0.0013283564241916622,
#                     'phase': 2.8750902281060404e-06}}
# loss: 0.000018
# step: 25
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18740696816493435,
#                     'length': 99.99936037146833,
#                     'omega_d': 3.6823844055235466,
#                     'phase': -9.123593621280605e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.009457962725424726,
#                     'length': -9.699204363218937e-06,
#                     'omega_d': 0.029566278960753516,
#                     'phase': 3.900866155234687e-06}}
# loss: 0.000021
# step: 26
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18443365456222227,
#                     'length': 99.99942909219385,
#                     'omega_d': 3.681213876677369,
#                     'phase': -8.42335669968518e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0018584959562170857,
#                     'length': 1.1158168602850166e-05,
#                     'omega_d': 0.0038239900627672374,
#                     'phase': 2.7463202385398605e-06}}
# loss: 0.000018
# step: 27
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18789609448345454,
#                     'length': 99.99934941260133,
#                     'omega_d': 3.6824205805317876,
#                     'phase': -9.182881273749149e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.004294313162706801,
#                     'length': -2.087947140332476e-06,
#                     'omega_d': 0.013359825976904128,
#                     'phase': 2.965643184090503e-06}}
# loss: 0.000019
# step: 28
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18500259759771223,
#                     'length': 99.9994159993604,
#                     'omega_d': 3.681412160479973,
#                     'phase': -8.548160660628241e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.001907828001685772,
#                     'length': 9.81961579714898e-06,
#                     'omega_d': 0.004379446834048502,
#                     'phase': 5.593984041003394e-06}}
# loss: 0.000017
# step: 29
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18667092548262618,
#                     'length': 99.99937432493435,
#                     'omega_d': 3.6819513099827184,
#                     'phase': -9.263390998428043e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0009562343349568654,
#                     'length': 6.030689244238063e-06,
#                     'omega_d': 0.00139164850181331,
#                     'phase': -1.4693792383689818e-05}}
# loss: 0.000018
# step: 30
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18518253992911038,
#                     'length': 99.99941150444458,
#                     'omega_d': 3.6814703120096417,
#                     'phase': -8.625303898258069e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0017763292072962029,
#                     'length': -1.350801535519261e-06,
#                     'omega_d': 0.004020814468759473,
#                     'phase': -1.9876069819766447e-06}}
# loss: 0.000017
# step: 31
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1861648743944308,
#                     'length': 99.99938696596783,
#                     'omega_d': 3.6817877706718725,
#                     'phase': -9.046441384370252e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0011333925434183188,
#                     'length': 8.612477676088498e-06,
#                     'omega_d': 0.0035710788941941737,
#                     'phase': 1.921586078757436e-05}}
# loss: 0.000018
# step: 32
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18531926461049328,
#                     'length': 99.9994080890952,
#                     'omega_d': 3.681514496995487,
#                     'phase': -8.683919258545053e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.001677987996703797,
#                     'length': 9.458695620453404e-06,
#                     'omega_d': 0.003637358942414053,
#                     'phase': 3.4714020030693746e-06}}
# loss: 0.000017
# step: 33
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1854213860715843,
#                     'length': 99.99940553812586,
#                     'omega_d': 3.681547499342007,
#                     'phase': -8.727699841350875e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0016114328620389022,
#                     'length': 9.371197355371805e-06,
#                     'omega_d': 0.0035037286920352123,
#                     'phase': 4.094161982459425e-06}}
# loss: 0.000017
# step: 34
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18579313023300756,
#                     'length': 99.99939625204685,
#                     'omega_d': 3.6816676350069395,
#                     'phase': -8.887070612860563e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0014303054922316203,
#                     'length': 9.456608869842327e-06,
#                     'omega_d': 0.0035580040407335247,
#                     'phase': 1.3525461317601454e-05}}
# loss: 0.000017
# step: 35
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18675948774476903,
#                     'length': 99.99936953058297,
#                     'omega_d': 3.6819591238377836,
#                     'phase': -9.762218285475622e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.00012611204479261756,
#                     'length': 7.172891048904234e-06,
#                     'omega_d': -0.0012077669635766628,
#                     'phase': -1.607322586660903e-05}}
# loss: 0.000018
# step: 36
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1858589768950308,
#                     'length': 99.99939443127226,
#                     'omega_d': 3.681687496772688,
#                     'phase': -8.94670232505586e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.001214053484175309,
#                     'length': 9.228980201659501e-06,
#                     'omega_d': 0.0036298025926375208,
#                     'phase': 1.8962012229486533e-05}}
# loss: 0.000017
# step: 37
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18580158623872253,
#                     'length': 99.9993960182236,
#                     'omega_d': 3.6816701856480734,
#                     'phase': -8.894728496853812e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0014176932039384816,
#                     'length': 9.465306773631099e-06,
#                     'omega_d': 0.00353759860053227,
#                     'phase': 1.377926012348883e-05}}
# loss: 0.000017
# step: 38
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.185839464071886,
#                     'length': 99.99939497083572,
#                     'omega_d': 3.681681610990319,
#                     'phase': -8.929031223467164e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0012426229856337318,
#                     'length': 9.23590709102485e-06,
#                     'omega_d': 0.0036993799701261396,
#                     'phase': 1.884834917451054e-05}}
# loss: 0.000017
# step: 39
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18580450480318725,
#                     'length': 99.99939593752022,
#                     'omega_d': 3.681671065994046,
#                     'phase': -8.897371592051599e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0014132779251702532,
#                     'length': 9.463460402124864e-06,
#                     'omega_d': 0.0035275623733309375,
#                     'phase': 1.3817347013441443e-05}}
# loss: 0.000017
# step: 40
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18580482455786293,
#                     'length': 99.99939592867845,
#                     'omega_d': 3.681671162443771,
#                     'phase': -8.897661166620858e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0012379350422582224,
#                     'length': -3.0278852482255726e-06,
#                     'omega_d': 0.003172379472970819,
#                     'phase': 5.102288110838714e-06}}
# loss: 0.000017
# step: 41
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1857450111248965,
#                     'length': 99.99939702795774,
#                     'omega_d': 3.6816327791020176,
#                     'phase': -8.951191610645329e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0005754496884471975,
#                     'length': 1.0671230690178565e-05,
#                     'omega_d': 0.0006838870898388308,
#                     'phase': 7.776433206239347e-06}}
# loss: 0.000017
# step: 42
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18581997892770807,
#                     'length': 99.99939550103731,
#                     'omega_d': 3.6816560143004367,
#                     'phase': -8.983239335467617e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0004902461701035081,
#                     'length': 1.0138943594165384e-05,
#                     'omega_d': 0.0005846251246519702,
#                     'phase': 1.0684973613674082e-05}}
# loss: 0.000017
# step: 43
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18574817704394106,
#                     'length': 99.9993969634753,
#                     'omega_d': 3.681633760333352,
#                     'phase': -8.952544998347046e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0005721624115071169,
#                     'length': 1.0703144316450934e-05,
#                     'omega_d': 0.0006873221759092229,
#                     'phase': 8.039379164281333e-06}}
# loss: 0.000017
# step: 44
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18574505329820254,
#                     'length': 99.99939702709877,
#                     'omega_d': 3.6816327921730307,
#                     'phase': -8.951209639164994e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0005755848740797542,
#                     'length': 1.0689212172108256e-05,
#                     'omega_d': 0.0006896838138673497,
#                     'phase': 7.89212608378891e-06}}
# loss: 0.000017
# step: 45
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1857450111382729,
#                     'length': 99.99939702795747,
#                     'omega_d': 3.6816327791061636,
#                     'phase': -8.951191616363559e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0005754498853068658,
#                     'length': 1.067128344091675e-05,
#                     'omega_d': 0.0006838871877064748,
#                     'phase': 7.77643494448417e-06}}
# loss: 0.000017
# step: 46
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1857450111516408,
#                     'length': 99.9993970279572,
#                     'omega_d': 3.6816327791103065,
#                     'phase': -8.951191622078151e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0005760071697374167,
#                     'length': 1.072695827351867e-05,
#                     'omega_d': 0.0007029152480233172,
#                     'phase': 8.146644975391825e-06}}
# loss: 0.000017
# step: 47
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1857450111382729,
#                     'length': 99.99939702795747,
#                     'omega_d': 3.6816327791061636,
#                     'phase': -8.951191616363559e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0005754498853068658,
#                     'length': 1.067128344091675e-05,
#                     'omega_d': 0.0006838871877064748,
#                     'phase': 7.77643494448417e-06}}
# loss: 0.000017
# step: 48
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18574501114495684,
#                     'length': 99.99939702795733,
#                     'omega_d': 3.681632779108235,
#                     'phase': -8.951191619220856e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0005760071945840706,
#                     'length': 1.0726985951941869e-05,
#                     'omega_d': 0.0007029150928795771,
#                     'phase': 8.14664201003562e-06}}
# loss: 0.000017
# step: 49
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1857450111382729,
#                     'length': 99.99939702795747,
#                     'omega_d': 3.6816327791061636,
#                     'phase': -8.951191616363559e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0005754498853068658,
#                     'length': 1.067128344091675e-05,
#                     'omega_d': 0.0006838871877064748,
#                     'phase': 7.77643494448417e-06}}
# loss: 0.000017
# step: 50
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18574501114161487,
#                     'length': 99.9993970279574,
#                     'omega_d': 3.681632779107199,
#                     'phase': -8.951191617792208e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.000576007185498468,
#                     'length': 1.0726969106828088e-05,
#                     'omega_d': 0.0007029152504297504,
#                     'phase': 8.146644437815414e-06}}
# loss: 0.000017
# step: 51
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1857450111382729,
#                     'length': 99.99939702795747,
#                     'omega_d': 3.6816327791061636,
#                     'phase': -8.951191616363559e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0005754498853068658,
#                     'length': 1.067128344091675e-05,
#                     'omega_d': 0.0006838871877064748,
#                     'phase': 7.77643494448417e-06}}
# loss: 0.000017
# step: 52
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18574501113994388,
#                     'length': 99.99939702795743,
#                     'omega_d': 3.6816327791066814,
#                     'phase': -8.951191617077884e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.000575449599678444,
#                     'length': 1.067118492499513e-05,
#                     'omega_d': 0.0006838881048441983,
#                     'phase': 7.776450585612178e-06}}
# loss: 0.000017
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 1.7077973705870164e-05
#         x: q1_pulse_cos:     amp: 0.18574501113994388
#                           length: 99.99939702795743
#                          omega_d: 3.6816327791066814
#                            phase: -8.951191617077884e-05
#       nit: 24
#       jac: q1_pulse_cos:     amp: -0.000575449599678444
#                           length: 1.067118492499513e-05
#                          omega_d: 0.0006838881048441983
#                            phase: 7.776450585612178e-06
#      nfev: 53
#      njev: 53
#  hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>
