# %% [markdown]
# # Simulating time evolution
#
# In this subsection, we detail the workflow for simulating the time evolution of a quantum system using common function "Evolve". Our focus is on implementing a Cross-resonance (CR) pulse in a system of three qubits. The code provided forms the basis of our discussion.
#
# Initially, we set up the pulse parameters for our time evolution. We specify the length of the CR pulse and calculate the effective coupling strength $J_{eff}$ and the detuning between the dressed 0-1 frequencies of qubits 1 and 2. The driving amplitude of the pulse $\epsilon_d$ is computed based on the detuning and the effective coupling strength.

# %%
import numpy as np
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt

fluxonium_1 = {
    "ec": 1.0 * 2 * np.pi,
    "ej": 4.0 * 2 * np.pi,
    "el": 0.9 * 2 * np.pi,
    "phiext": np.pi,
    "system_type": "fluxonium",
    "arguments": {"phi_max": 5 * np.pi},
}

fluxonium_2 = {
    "ec": 1.0 * 2 * np.pi,
    "ej": 4.0 * 2 * np.pi,
    "el": 1.0 * 2 * np.pi,
    "phiext": np.pi,
    "system_type": "fluxonium",
    "arguments": {"phi_max": 5 * np.pi},
}

fluxonium_3 = {
    "ec": 1.0 * 2 * np.pi,
    "ej": 4.0 * 2 * np.pi,
    "el": 1.1 * 2 * np.pi,
    "phiext": np.pi,
    "system_type": "fluxonium",
    "arguments": {"phi_max": 5 * np.pi},
}

coupling = {
    "capacitive_coupling": {"strength": 20.0e-3 * 2 * np.pi},
    "inductive_coupling": {"strength": -1.0 * 2e-3 * 2 * np.pi},
}

# %%
from supergrad.scgraph.graph import SCGraph


class MultipathThreeQubit(SCGraph):
    def __init__(self):
        super().__init__()

        # nodes represent qubits
        self.add_node("q1", **fluxonium_1)
        self.add_node("q2", **fluxonium_2)
        self.add_node("q3", **fluxonium_3)
        # edges represent two-qubit interactions
        self.add_edge("q1", "q2", **coupling)
        self.add_edge("q2", "q3", **coupling)

# %%
from supergrad.helper import Spectrum


chain_3q = MultipathThreeQubit()
spec = Spectrum(chain_3q, share_params=True, unify_coupling=True)
params = spec.all_params
energy = spec.energy_tensor(params)
dressed_freq_q1 = (energy[1, 0, 0] - energy[0, 0, 0])
dressed_freq_q2 = (energy[0, 1, 0] - energy[0, 0, 0])

# %%
from supergrad.helper import Evolve
from supergrad.utils import tensor, compute_fidelity_with_1q_rotation_axis
from supergrad.utils.gates import cnot

length = 100.0
detuning = jnp.abs(dressed_freq_q1 - dressed_freq_q2)
j_eff = 0.01 * 2 * np.pi
tau_eps_drive = np.pi / 2.0 * detuning / j_eff

cr_pulse = {
    "pulse": {
        "amp": tau_eps_drive / length,
        "omega_d": dressed_freq_q2,
        "phase": 0.0,
        "length": length,
        "pulse_type": "cos",
        "operator_type": "phi_operator",
        "delay": 0.0,
    }
}

cr_chain_3q = MultipathThreeQubit()
cr_chain_3q.add_node("q1", **cr_pulse)

# %% [markdown]
# The Evolve class is then utilized to simulate the time evolution. We specify parameters such as the truncated dimension, parameter sharing, and compensation options. The unitary evolution of the CR pulse is computed using the eigen\_basis method of the Evolve class.

# %%
target_unitary = tensor(cnot(), jnp.eye(2))
evo = Evolve(cr_chain_3q, truncated_dim=3, share_params=True, unify_coupling=True, compensation_option='no_comp')
params = evo.pulse_params
cr_unitary = evo.eigen_basis(evo.all_params)
fideity, res_unitary = compute_fidelity_with_1q_rotation_axis(target_unitary, cr_unitary, compensation_option='arbit_single')
print(fideity)  # 0.98824
# Out:
# 0.9882389768200738

# %% [markdown]
# The CR pulse, which contains an effective ZX term, can be utilized to implement a CNOT unitary. It is well-established that single-qubit gates generally exhibit lower error rates compared to two-qubit gates. Therefore, we can introduce virtual single-qubit rotations to simulate a CNOT unitary more accurately. For instance, we simulate a 3-qubit gate that is composed of a tensor product between a CNOT gate and an identity operation, and the possible compensations are calculated using a differentiable optimizer within the `compute_fidelity_with_1q_rotation_axis` function. Additionally, we compute the fidelity of the resultant unitary against the target unitary. The high fidelity(0.98824) indicates a successful implementation of the CNOT gate, demonstrating the effectiveness of our approach in simulating quantum gate operations in a multi-qubit system.
#
# Furthermore, we conduct pulse parameter optimization to simulate device calibration. This optimization process utilizes automatic differentiation to obtain gradients. After optimization, the fidelity of the $CNOT\otimes I$ gate is significantly enhanced, reaching up to 99.99\%. Consider the following code as an example:

# %%
import haiku as hk
from supergrad.utils.optimize import scipy_minimize

def infidelity(params):
    params = hk.data_structures.merge(evo.all_params, params)
    cr_unitary = evo.eigen_basis(params)
    fideity, res_unitary = compute_fidelity_with_1q_rotation_axis(target_unitary, cr_unitary, compensation_option='arbit_single')
    return jnp.abs(1 - fideity)

scipy_minimize(infidelity, params, method='L-BFGS-B', logging=True)
# Out:
# /Users/allegro/anaconda3/envs/supergrad/lib/python3.10/site-packages/jax/_src/lax/lax.py:2690: ComplexWarning: Casting complex values to real discards the imaginary part
#   x_bar = _convert_element_type(x_bar, x.aval.dtype, x.aval.weak_type)
# step: 0
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.13067653633650167,
#                     'length': 100.0,
#                     'omega_d': 3.6580304111499444,
#                     'phase': 0.0}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.8874590856781176,
#                     'length': -0.0013356914983933556,
#                     'omega_d': -0.044297163397486565,
#                     'phase': 1.0894022522447643e-05}}
# loss: 0.011761
# step: 1
# parameters:
# { 'q1_pulse_cos': { 'amp': 1.129431997274138,
#                     'length': 100.00150320076686,
#                     'omega_d': 3.7078828883641255,
#                     'phase': -1.2260243499065988e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': 0.21603797507809724,
#                     'length': 0.015263899383910866,
#                     'omega_d': 16.561186380099127,
#                     'phase': -5.798660210690625e-06}}
# loss: 0.236806
# step: 2
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.4848870500230471,
#                     'length': 100.00053311299575,
#                     'omega_d': 3.67571068650584,
#                     'phase': -4.3481185511109384e-06}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.1138179384139363,
#                     'length': -0.003004919201675125,
#                     'omega_d': -13.918272525993405,
#                     'phase': 2.3470215290736418e-05}}
# loss: 0.133322
# step: 3
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1814219944171421,
#                     'length': 100.000076375664,
#                     'omega_d': 3.660563350284328,
#                     'phase': -6.2292692943698e-07}}
# gradient:
# { 'q1_pulse_cos': { 'amp': 0.5783113156962282,
#                     'length': 0.0013675086153327061,
#                     'omega_d': -0.10711210501782514,
#                     'phase': -6.466296768549179e-07}}
# loss: 0.007104
# step: 4
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.16166572954388783,
#                     'length': 100.00003621431915,
#                     'omega_d': 3.6624293358141755,
#                     'phase': -5.157469167244193e-07}}
# gradient:
# { 'q1_pulse_cos': { 'amp': 0.08428845637839474,
#                     'length': 0.00019312151953435804,
#                     'omega_d': -0.030073199968312002,
#                     'phase': 5.5129629801369554e-06}}
# loss: 0.000199
# step: 5
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.15833691361391128,
#                     'length': 100.0000296973173,
#                     'omega_d': 3.663426626280224,
#                     'phase': -7.589255675630251e-07}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0179807134939934,
#                     'length': -5.725133257400926e-06,
#                     'omega_d': 0.0046672322234643055,
#                     'phase': 6.995442790286496e-06}}
# loss: 0.000073
# step: 6
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1589244043532403,
#                     'length': 100.00002990024409,
#                     'omega_d': 3.6632991990661417,
#                     'phase': -9.340307110361417e-07}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0001089719416528909,
#                     'length': 2.7948799583782835e-05,
#                     'omega_d': -0.0025592766254291526,
#                     'phase': 6.598814124481347e-06}}
# loss: 0.000068
# step: 7
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.15894119667794812,
#                     'length': 100.00002905916784,
#                     'omega_d': 3.663376994009338,
#                     'phase': -1.1371398177841204e-06}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.000507034414536776,
#                     'length': 2.715507161430964e-05,
#                     'omega_d': -0.0024039890482330656,
#                     'phase': 6.581699709867847e-06}}
# loss: 0.000068
# step: 8
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.15900836597677945,
#                     'length': 100.00002569486287,
#                     'omega_d': 3.663688173782123,
#                     'phase': -1.9495762447760352e-06}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.002250766458300936,
#                     'length': 2.372306963359591e-05,
#                     'omega_d': -0.0016606832123490225,
#                     'phase': 6.536386786896941e-06}}
# loss: 0.000067
# step: 9
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.16032128748591148,
#                     'length': 99.99998095167732,
#                     'omega_d': 3.667746590491075,
#                     'phase': -1.290127341379387e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.034592745294479886,
#                     'length': -3.723872617862346e-05,
#                     'omega_d': 0.025269586825771188,
#                     'phase': 6.313771980748137e-06}}
# loss: 0.000078
# step: 10
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1594342051866209,
#                     'length': 100.00001118264515,
#                     'omega_d': 3.665004499969581,
#                     'phase': -5.501701818497952e-06}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.008368519377863324,
#                     'length': 1.1681889152505582e-05,
#                     'omega_d': 0.001905272258454822,
#                     'phase': 6.3373669479078975e-06}}
# loss: 0.000065
# step: 11
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1601129678684564,
#                     'length': 99.99999398188945,
#                     'omega_d': 3.6664650258810796,
#                     'phase': -9.769312079617064e-06}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.014631900437665726,
#                     'length': -6.910878680413918e-06,
#                     'omega_d': 0.007260083023673453,
#                     'phase': 2.9317618154995857e-06}}
# loss: 0.000063
# step: 12
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1605833678032083,
#                     'length': 99.9999870049604,
#                     'omega_d': 3.666889709554901,
#                     'phase': -1.1489428975949295e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.010089908077630315,
#                     'length': 4.581316845989216e-06,
#                     'omega_d': 0.004522372494935704,
#                     'phase': 3.8103103020990153e-06}}
# loss: 0.000060
# step: 13
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.16289077547532413,
#                     'length': 99.99994602323108,
#                     'omega_d': 3.6696854745912764,
#                     'phase': -2.1527230458650548e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.013880940199877711,
#                     'length': -5.375717573760948e-06,
#                     'omega_d': 0.011185175553699914,
#                     'phase': 1.3416194098503478e-06}}
# loss: 0.000053
# step: 14
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1647887725952382,
#                     'length': 99.99991455259499,
#                     'omega_d': 3.6708790705214875,
#                     'phase': -2.8987018475376982e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': 0.0010705745100695158,
#                     'length': 2.4549218553143876e-05,
#                     'omega_d': -0.00419812740783884,
#                     'phase': 6.037327804017301e-06}}
# loss: 0.000046
# step: 15
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1700559848827259,
#                     'length': 99.99982309907992,
#                     'omega_d': 3.6758045552388356,
#                     'phase': -5.1038717490723405e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.04135596949423098,
#                     'length': -3.916162378086022e-05,
#                     'omega_d': 0.07069710582242879,
#                     'phase': 5.188233346741447e-06}}
# loss: 0.000072
# step: 16
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.16639346895752652,
#                     'length': 99.9998866905847,
#                     'omega_d': 3.6723796569753904,
#                     'phase': -3.5705236625851655e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.005771062968411655,
#                     'length': 2.3318214729356986e-05,
#                     'omega_d': 0.004693239399636213,
#                     'phase': 6.504960012138084e-06}}
# loss: 0.000042
# step: 17
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.17072185650814042,
#                     'length': 99.99981178049191,
#                     'omega_d': 3.67595976575225,
#                     'phase': -5.365663192649406e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.03318590068301511,
#                     'length': -2.482335150455369e-05,
#                     'omega_d': 0.05719425321698155,
#                     'phase': 5.027755148181974e-06}}
# loss: 0.000057
# step: 18
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1675372631582446,
#                     'length': 99.99986689528478,
#                     'omega_d': 3.6733257154345806,
#                     'phase': -4.044896661758042e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.010144492774698142,
#                     'length': 2.7540311481138554e-05,
#                     'omega_d': 0.011527418909866548,
#                     'phase': 6.008062313153064e-06}}
# loss: 0.000041
# step: 19
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.16943012225094478,
#                     'length': 99.99983371068377,
#                     'omega_d': 3.6746392009936852,
#                     'phase': -4.827887586811767e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.012948293067346028,
#                     'length': 1.0222287857288934e-05,
#                     'omega_d': 0.018144146085436876,
#                     'phase': 5.235594675388075e-06}}
# loss: 0.000038
# step: 20
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.17105433800464112,
#                     'length': 99.99980485126218,
#                     'omega_d': 3.6754297839879286,
#                     'phase': -5.533882162790965e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.006860860612496659,
#                     'length': 2.225467731462614e-05,
#                     'omega_d': 0.00901152163311002,
#                     'phase': 5.035407906188748e-06}}
# loss: 0.000033
# step: 21
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.174728978154402,
#                     'length': 99.99973911367472,
#                     'omega_d': 3.6774388993366687,
#                     'phase': -7.120558750245186e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.010179359626203933,
#                     'length': 1.3071805991116585e-05,
#                     'omega_d': 0.01821928638412515,
#                     'phase': 3.571049008017865e-06}}
# loss: 0.000029
# step: 22
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.17770863215973035,
#                     'length': 99.99968187682163,
#                     'omega_d': 3.6785997874799965,
#                     'phase': -8.485460806638367e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0018602790344360433,
#                     'length': 2.294784775541184e-05,
#                     'omega_d': 0.0017602872888075067,
#                     'phase': 3.860703042153894e-06}}
# loss: 0.000023
# step: 23
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.183415414917169,
#                     'length': 99.99957548570471,
#                     'omega_d': 3.681271473038497,
#                     'phase': -0.00011031405597033571}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.01969670925040175,
#                     'length': -1.9329395375425688e-05,
#                     'omega_d': 0.05451462414267347,
#                     'phase': 2.8078477350477766e-06}}
# loss: 0.000030
# step: 24
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.17950332476145475,
#                     'length': 99.99964841850395,
#                     'omega_d': 3.679439990184353,
#                     'phase': -9.286120035126653e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.006365152887614965,
#                     'length': -2.83966989981921e-06,
#                     'omega_d': 0.01279820461017984,
#                     'phase': -1.1320001561155127e-06}}
# loss: 0.000022
# step: 25
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1853192383061038,
#                     'length': 99.99953769502797,
#                     'omega_d': 3.681874079116465,
#                     'phase': -0.00011925739224869278}}
# gradient:
# { 'q1_pulse_cos': { 'amp': 0.022817536055773947,
#                     'length': 4.4288277507505324e-05,
#                     'omega_d': -0.07804036329058608,
#                     'phase': -0.00025173611617148537}}
# loss: 0.000027
# step: 26
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.179711063346398,
#                     'length': 99.99964446357271,
#                     'omega_d': 3.6795269333939626,
#                     'phase': -9.380404578914388e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.006581274739002828,
#                     'length': -4.985468288689854e-06,
#                     'omega_d': 0.013460860000430284,
#                     'phase': -1.4472894362292464e-06}}
# loss: 0.000021
# step: 27
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1829243304124366,
#                     'length': 99.99958328933135,
#                     'omega_d': 3.680871756995847,
#                     'phase': -0.00010838782758742593}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.010216665313721231,
#                     'length': -4.16463761567459e-07,
#                     'omega_d': 0.026613194198648323,
#                     'phase': 3.002106523063709e-06}}
# loss: 0.000021
# step: 28
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1813400146422062,
#                     'length': 99.99961345156602,
#                     'omega_d': 3.6802086856740877,
#                     'phase': -0.00010119722841911526}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.00911372980007707,
#                     'length': -1.686749528908548e-05,
#                     'omega_d': 0.021410073256339274,
#                     'phase': -2.6048048208925154e-06}}
# loss: 0.000021
# step: 29
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18331327989406157,
#                     'length': 99.99957403949652,
#                     'omega_d': 3.6808709997403,
#                     'phase': -0.00011052727776301828}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.004185933074079703,
#                     'length': 9.604339489145197e-06,
#                     'omega_d': 0.00996681587506353,
#                     'phase': 2.9812099758564602e-06}}
# loss: 0.000019
# step: 30
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18466587816543278,
#                     'length': 99.9995463994568,
#                     'omega_d': 3.6813084067387623,
#                     'phase': -0.00011706376464669874}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0024457037121155076,
#                     'length': 9.41430680943459e-06,
#                     'omega_d': 0.0056105226268346915,
#                     'phase': 2.6410266652783806e-06}}
# loss: 0.000017
# step: 31
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18792554936594555,
#                     'length': 99.99948044123337,
#                     'omega_d': 3.682414471662052,
#                     'phase': -0.0001326902399937208}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0019846370922763272,
#                     'length': -1.613974338350993e-05,
#                     'omega_d': 0.005406822985800452,
#                     'phase': -1.622828317040677e-05}}
# loss: 0.000019
# step: 32
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1851053310863014,
#                     'length': 99.99953750729188,
#                     'omega_d': 3.6814575209994684,
#                     'phase': -0.00011917044958874128}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0023994115746351595,
#                     'length': -2.5339126386047408e-06,
#                     'omega_d': 0.00582303238348258,
#                     'phase': -2.0862506885095717e-06}}
# loss: 0.000017
# step: 33
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1868327705278868,
#                     'length': 99.99954173007878,
#                     'omega_d': 3.681957460095287,
#                     'phase': -0.00010774398656172552}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -1.825413765416198e-05,
#                     'length': -1.8767397403125519e-06,
#                     'omega_d': -0.001049851830144594,
#                     'phase': -2.1083605945503417e-05}}
# loss: 0.000018
# step: 34
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18537426365354587,
#                     'length': 99.99953816470706,
#                     'omega_d': 3.6815353529056227,
#                     'phase': -0.00011739154610743647}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0017719184375203033,
#                     'length': 8.968375487044612e-06,
#                     'omega_d': 0.003947720977627153,
#                     'phase': 3.754052824854531e-06}}
# loss: 0.000017
# step: 35
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.191812792939358,
#                     'length': 99.99951828898851,
#                     'omega_d': 3.6835994313091542,
#                     'phase': -9.328309750814045e-05}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.004048246002048756,
#                     'length': -1.4958670055602029e-05,
#                     'omega_d': 0.01567986438280911,
#                     'phase': 1.2330714518937751e-05}}
# loss: 0.000019
# step: 36
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18760702217076752,
#                     'length': 99.99953127218892,
#                     'omega_d': 3.68225113572358,
#                     'phase': -0.0001090311983389338}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0009099389258989767,
#                     'length': 4.469568310048493e-06,
#                     'omega_d': 0.0026379571305920214,
#                     'phase': 6.145464005970868e-06}}
# loss: 0.000018
# step: 37
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18563593126588077,
#                     'length': 99.99953735694001,
#                     'omega_d': 3.6816192389056,
#                     'phase': -0.00011641175710562551}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0015078243551771466,
#                     'length': 9.005738683777873e-06,
#                     'omega_d': 0.004253543123362449,
#                     'phase': 1.6814078143784953e-05}}
# loss: 0.000017
# step: 38
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18541610404428896,
#                     'length': 99.99953803554591,
#                     'omega_d': 3.6815487661935173,
#                     'phase': -0.00011723487882134875}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0016668020497414382,
#                     'length': -2.02185293090613e-06,
#                     'omega_d': 0.00387375124586397,
#                     'phase': -1.647265159375064e-06}}
# loss: 0.000017
# step: 39
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1853794676791244,
#                     'length': 99.99953814864226,
#                     'omega_d': 3.681537021224012,
#                     'phase': -0.00011737206013826557}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0017682756645585984,
#                     'length': 8.971917654105028e-06,
#                     'omega_d': 0.003941329927139068,
#                     'phase': 3.8129194685692344e-06}}
# loss: 0.000017
# step: 40
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18537476391360486,
#                     'length': 99.99953816316275,
#                     'omega_d': 3.6815355132801333,
#                     'phase': -0.00011738967293215321}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0017338795873867525,
#                     'length': -1.5668148590731713e-06,
#                     'omega_d': 0.004004237152421069,
#                     'phase': -1.5630964465296937e-06}}
# loss: 0.000017
# step: 41
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1853742693554626,
#                     'length': 99.99953816468945,
#                     'omega_d': 3.681535354733556,
#                     'phase': -0.0001173915247571621}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0017720251124644889,
#                     'length': 8.972047189010401e-06,
#                     'omega_d': 0.003948437217373222,
#                     'phase': 3.764239338616592e-06}}
# loss: 0.000017
# step: 42
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18537426365508772,
#                     'length': 99.99953816470706,
#                     'omega_d': 3.681535352906117,
#                     'phase': -0.00011739154610166321}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0017719186110762661,
#                     'length': 8.968406645458825e-06,
#                     'omega_d': 0.003947720983479626,
#                     'phase': 3.7540524237844775e-06}}
# loss: 0.000017
# step: 43
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18537426365355852,
#                     'length': 99.99953816470706,
#                     'omega_d': 3.6815353529056267,
#                     'phase': -0.0001173915461073891}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0017719184817142656,
#                     'length': 8.968401589547852e-06,
#                     'omega_d': 0.003947720537321692,
#                     'phase': 3.754045539031827e-06}}
# loss: 0.000017
# step: 44
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18537426365354587,
#                     'length': 99.99953816470706,
#                     'omega_d': 3.6815353529056227,
#                     'phase': -0.00011739154610743644}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0017719184375203033,
#                     'length': 8.968375487044612e-06,
#                     'omega_d': 0.003947720977627153,
#                     'phase': 3.754052824854531e-06}}
# loss: 0.000017
# step: 45
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1853742636535459,
#                     'length': 99.99953816470706,
#                     'omega_d': 3.6815353529056227,
#                     'phase': -0.00011739154610743641}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0017719182180199174,
#                     'length': 8.968413220989757e-06,
#                     'omega_d': 0.003947720934595894,
#                     'phase': 3.754052642190106e-06}}
# loss: 0.000017
# step: 46
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1853742636535522,
#                     'length': 99.99953816470706,
#                     'omega_d': 3.681535352905625,
#                     'phase': -0.00011739154610741275}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.001771918399824971,
#                     'length': 8.968385420026428e-06,
#                     'omega_d': 0.003947721369232214,
#                     'phase': 3.754059187415939e-06}}
# loss: 0.000017
# step: 47
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1853742636535459,
#                     'length': 99.99953816470706,
#                     'omega_d': 3.6815353529056227,
#                     'phase': -0.0001173915461074364}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0017719182180199174,
#                     'length': 8.968413220989757e-06,
#                     'omega_d': 0.003947720934595894,
#                     'phase': 3.754052642190106e-06}}
# loss: 0.000017
# step: 48
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18537426365354903,
#                     'length': 99.99953816470706,
#                     'omega_d': 3.6815353529056236,
#                     'phase': -0.00011739154610742458}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0017719183600754264,
#                     'length': 8.968362651482288e-06,
#                     'omega_d': 0.003947720951940382,
#                     'phase': 3.7540525831488794e-06}}
# loss: 0.000017
# step: 49
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1853742636535459,
#                     'length': 99.99953816470706,
#                     'omega_d': 3.6815353529056227,
#                     'phase': -0.0001173915461074364}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0017719182180199174,
#                     'length': 8.968413220989757e-06,
#                     'omega_d': 0.003947720934595894,
#                     'phase': 3.754052642190106e-06}}
# loss: 0.000017
# step: 50
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18537426365354748,
#                     'length': 99.99953816470706,
#                     'omega_d': 3.681535352905623,
#                     'phase': -0.00011739154610743049}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0017719184163456792,
#                     'length': 8.968406666841814e-06,
#                     'omega_d': 0.003947720952428942,
#                     'phase': 3.754052410636494e-06}}
# loss: 0.000017
# step: 51
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18714618209106618,
#                     'length': 99.99952919633158,
#                     'omega_d': 3.6775876319279956,
#                     'phase': -0.000121145598932291}}
# gradient:
# { 'q1_pulse_cos': { 'amp': 0.19785926910222743,
#                     'length': 0.0003839306938310905,
#                     'omega_d': -0.48720344191846515,
#                     'phase': -8.264617366943333e-07}}
# loss: 0.001203
# step: 52
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18538682213614166,
#                     'length': 99.99953810114364,
#                     'omega_d': 3.681507373409422,
#                     'phase': -0.00011741815297943822}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0003708891249804943,
#                     'length': 1.1352310545744045e-05,
#                     'omega_d': -0.00022475670552159647,
#                     'phase': 3.2925975740639763e-06}}
# loss: 0.000017
# step: 53
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1853894782979397,
#                     'length': 99.99953802279185,
#                     'omega_d': 3.681508655896771,
#                     'phase': -0.00011744095305512954}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0003873401051446666,
#                     'length': 1.1306044619335583e-05,
#                     'omega_d': -0.00017599813681918602,
#                     'phase': 3.2754701248102974e-06}}
# loss: 0.000017
# step: 54
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18540010294513184,
#                     'length': 99.9995377093847,
#                     'omega_d': 3.681513785846168,
#                     'phase': -0.00011753215335789482}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.00045345604928006986,
#                     'length': 1.1163481907844635e-05,
#                     'omega_d': 2.5437914855657363e-05,
#                     'phase': 3.3386765619839616e-06}}
# loss: 0.000017
# step: 55
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18544260153390044,
#                     'length': 99.99953645575607,
#                     'omega_d': 3.6815343056437553,
#                     'phase': -0.00011789695456895595}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.000719895092884846,
#                     'length': 1.0653719058960721e-05,
#                     'omega_d': 0.0008478306691553908,
#                     'phase': 3.815155322033497e-06}}
# loss: 0.000017
# step: 56
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18540412947684023,
#                     'length': 99.99953759060956,
#                     'omega_d': 3.681515729995798,
#                     'phase': -0.00011756671647366298}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.00047880147132412757,
#                     'length': 1.114505977776044e-05,
#                     'omega_d': 0.00010613830118118884,
#                     'phase': 3.4516870251992765e-06}}
# loss: 0.000017
# step: 57
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1854001734487456,
#                     'length': 99.99953770730497,
#                     'omega_d': 3.6815138198877664,
#                     'phase': -0.00011753275854984189}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.00036789399546934725,
#                     'length': 5.324366603692401e-07,
#                     'omega_d': -5.831785109329007e-05,
#                     'phase': -1.8367061642836743e-06}}
# loss: 0.000017
# step: 58
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.1854773533281947,
#                     'length': 99.99953761849427,
#                     'omega_d': 3.6815442089992927,
#                     'phase': -0.00011709568859174884}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0006392356815123031,
#                     'length': 1.0726349345536049e-05,
#                     'omega_d': 0.0006260919370330313,
#                     'phase': 4.006281564668083e-06}}
# loss: 0.000017
# step: 59
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18541103713065574,
#                     'length': 99.99953769480416,
#                     'omega_d': 3.6815180973969244,
#                     'phase': -0.00011747123747684865}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0004797022634477305,
#                     'length': 1.1100341283393695e-05,
#                     'omega_d': 0.00010935678685996651,
#                     'phase': 3.4161161710973725e-06}}
# loss: 0.000017
# step: 60
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18542016810018644,
#                     'length': 99.99953768429717,
#                     'omega_d': 3.681521692661045,
#                     'phase': -0.00011741952876081258}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0005016008247869301,
#                     'length': 1.1065464188678096e-05,
#                     'omega_d': 0.0001815274892002794,
#                     'phase': 3.533210706076405e-06}}
# loss: 0.000017
# step: 61
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18541152444504436,
#                     'length': 99.9995376942434,
#                     'omega_d': 3.6815182892740226,
#                     'phase': -0.00011746847781356677}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.00048090563622146186,
#                     'length': 1.1102949366258687e-05,
#                     'omega_d': 0.00011385392026232101,
#                     'phase': 3.4359167788836693e-06}}
# loss: 0.000017
# step: 62
# parameters:
# { 'q1_pulse_cos': { 'amp': 0.18541103713065574,
#                     'length': 99.99953769480416,
#                     'omega_d': 3.6815180973969244,
#                     'phase': -0.00011747123747684865}}
# gradient:
# { 'q1_pulse_cos': { 'amp': -0.0004797022634477305,
#                     'length': 1.1100341283393695e-05,
#                     'omega_d': 0.00010935678685996651,
#                     'phase': 3.4161161710973725e-06}}
# loss: 0.000017
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 1.7036827077987482e-05
#         x: q1_pulse_cos:     amp: 0.18541103713065574
#                           length: 99.99953769480416
#                          omega_d: 3.6815180973969244
#                            phase: -0.00011747123747684865
#       nit: 25
#       jac: q1_pulse_cos:     amp: -0.0004797022634477305
#                           length: 1.1100341283393695e-05
#                          omega_d: 0.00010935678685996651
#                            phase: 3.4161161710973725e-06
#      nfev: 63
#      njev: 63
#  hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>
